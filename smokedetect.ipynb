# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 606.2 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.1/723.1 kB 5.1 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
# import numpy as np
# from PIL import Image
# import requests
# from io import BytesIO
import cv2

# %%
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 70.7MB/s]

# %%
model = YOLO('yolov8n.yaml')  # build a new model from YAML
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
model = YOLO('yolov8n.yaml').load('yolov8n.pt')  # build from YAML and transfer weights
# print("hello")
# Train the model
results = model.train(data='/kaggle/input/smoke-detect/datasets/fire-8/data.yaml', epochs=3, imgsz=640)
# Out:
# Transferred 355/355 items from pretrained weights
# Ultralytics YOLOv8.1.35 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Used to change filepaths
from pathlib import Path
import matplotlib.pyplot as plt
import IPython
from IPython.display import display
from PIL import Image
# %matplotlib inline
import os
# print(os.listdir("../input"))
# Out:
# ['smoke-demo', 'smoke-detection', 'smoke-detect']

# %%
IPython.display.Image(filename='/kaggle/input/smoke-demo/smoke_demo.jpg')

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
def create_model(num_classes):
    # load Faster RCNN pre-trained model
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    # get the number of input features
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # define a new head for the detector with required number of classes
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    return model

# %%
import torch
DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device('gpu')

# %%
# !pip install deepsparse[yolov8]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.2/150.2 kB 2.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.6/612.6 kB 6.7 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 62.4 MB/s eta 0:00:0000:01:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 24.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 73.1 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 MB 30.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 73.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic
# ...

# %%
# !pip uninstall daal==2021.5.0
# Out:
# Found existing installation: daal 2024.1.0
# Uninstalling daal-2024.1.0:
#   Would remove:
#     /opt/conda/lib/libonedal.so.2
#     /opt/conda/lib/libonedal_core.so.2
#     /opt/conda/lib/libonedal_dpc.so.2
#     /opt/conda/lib/libonedal_parameters.so.2
#     /opt/conda/lib/libonedal_parameters_dpc.so.2
#     /opt/conda/lib/libonedal_thread.so.2
#     /opt/conda/lib/python3.10/site-packages/daal-2024.1.0.dist-info/*
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user

# %%
checkpoint = torch.load("runs/detect/train3/weights/best.pt")
    model = checkpoint['model']

# %%
# !pip install ultralytics

# %%
# Export YOLOv8 model to ONNX format
# !yolo task=detect mode=export model=/kaggle/working/runs/detect/train2/weights/best.pt format=onnx opset=13
# Out:
# WARNING ⚠️ /kaggle/working/runs/detect/train2/weights/best.pt appears to require 'ultralytics.utils', which is not in ultralytics requirements.
# AutoInstall will run now for 'ultralytics.utils' but this feature will be removed in the future.
# Recommend fixes are to train a new model using the latest 'ultralytics' package or to run a command with an official YOLOv8 model, i.e. 'yolo predict model=yolov8n.pt'
# requirements: Ultralytics requirement "ultralytics.utils" not found, attempting AutoUpdate...
# ERROR: Could not find a version that satisfies the requirement ultralytics.utils (from versions: none)
# ERROR: No matching distribution found for ultralytics.utils
# requirements: ❌ Command 'pip install --no-cache "ultralytics.utils"  ' returned non-zero exit status 1.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/ultralytics/nn/tasks.py", line 518, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
# ...

# %%
# !pip install --upgrade ultralytics
# Out:
# ...
#   Using cached ultralytics-8.1.35-py3-none-any.whl.metadata (40 kB)
# ...
# Using cached ultralytics-8.1.35-py3-none-any.whl (723 kB)
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.124
#     Uninstalling ultralytics-8.0.124:
#       Successfully uninstalled ultralytics-8.0.124
# ...

# %%
import tensorflow as tf

# %%
model=tf.saved_model.load("/kaggle/working/runs/detect/train/weights/best.pt")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 model=tf.saved_model.load("/kaggle/working/runs/detect/train/weights/best.pt")
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/saved_model/load.py:912, in load(export_dir, tags, options)
#     910 if isinstance(export_dir, os.PathLike):
#     911   export_dir = os.fspath(export_dir)
# --> 912 result = load_partial(export_dir, None, tags, options)["root"]
#     913 return result
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/saved_model/load.py:1017, in load_partial(export_dir, filters, tags, options)
#    1012 if tags is not None and not isinstance(tags, set):
#    1013   # Supports e.g. tags=SERVING and tags=[SERVING]. Sets aren't considered
#    1014   # sequences for nest.flatten, so we put those through as-is.
#    1015   tags = nest.flatten(tags)
# ...

# %%
from deepsparse import Pipeline

# Specify the path to your YOLOv8 ONNX model
model_path = "/kaggle/working/yolov8n.onnx"

# Set up the DeepSparse Pipeline
yolo_pipeline = Pipeline.create(
    task="yolov8",
    model_path=model_path
)

# Run the model on your images
images = ["/kaggle/input/smoke-demo/smoke_demo.jpg"]
pipeline_outputs = yolo_pipeline(images=images)

# %%
# # Run the model on your images
# images = ["path/to/image.jpg"]
# pipeline_outputs = yolo_pipeline(images=images)

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO
def test():
    # Load the YOLO model
    yolo_model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt")
    
    # Set the model to evaluation mode
    yolo_model.eval()
    
    # Make predictions
    result = yolo_model.predict("/kaggle/input/smoke-demo/smoke_demo.jpg")

if __name__ == "__main__":
    test()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageOps

# %%
# # Function to test the uploaded image
# def test_uploaded_image(uploaded_image_path):
#     # Load the uploaded image
#     uploaded_image = Image.open(uploaded_image_path)
    
#     # Display the uploaded image
#     plt.imshow(uploaded_image)
#     plt.axis('off')
#     plt.title('Uploaded Image')
#     plt.show()
    
#     # Get image dimensions
#     width, height = uploaded_image.size
#     print("Image dimensions:", width, "x", height)
    
#     # Get image format
#     image_format = uploaded_image.format
#     print("Image format:", image_format)
    
#     # Get image mode
#     image_mode = uploaded_image.mode
#     print("Image mode:", image_mode)
    
#     # Convert image to numpy array
#     image_array = np.array(uploaded_image)
#     print("Image array shape:", image_array.shape)

# # Path to the uploaded image
# uploaded_image_path = "/kaggle/input/smoke-detect/datasets/fire-8/test/images/L_02374_png.rf.a34c0210242536a672fca80552a2afbe.jpg"  # Replace with the actual path to your uploaded image

# # Test the uploaded image
# test_uploaded_image(uploaded_image_path)



#  # Static dimensions for the image
# STATIC_WIDTH = 1840
# STATIC_HEIGHT = 1040

# # Function to test the uploaded image
# def test_uploaded_image(uploaded_image_path):
#     # Load the uploaded image
#     uploaded_image = Image.open(uploaded_image_path)
    
#     # Resize the image to the static dimensions
#     uploaded_image = ImageOps.fit(uploaded_image, (STATIC_WIDTH, STATIC_HEIGHT), method=0, bleed=0.0, centering=(0.5, 0.5))
    
#     # Display the uploaded image
#     plt.imshow(uploaded_image)
#     plt.axis('off')
#     plt.title('Uploaded Image')
#     plt.show()
    
#     # Get image dimensions
#     width, height = uploaded_image.size
#     print("Image dimensions:", width, "x", height)
    
#     # Get image format
#     image_format = uploaded_image.format
#     print("Image format:", image_format)
    
#     # Get image mode
#     image_mode = uploaded_image.mode
#     print("Image mode:", image_mode)
    
#     # Convert image to numpy array
#     image_array = np.array(uploaded_image)
#     print("Image array shape:", image_array.shape)

# # Path to the uploaded image
# uploaded_image_path = "/kaggle/input/smoke-demo/smoke_demo.jpg"  # Replace with the actual path to your uploaded image

# # Test the uploaded image
# test_uploaded_image(uploaded_image_path)


def test_uploaded_image(uploaded_image_path):
    # Load the uploaded image
    uploaded_image = Image.open(uploaded_image_path)
    
    # Resize the image to the desired dimensions
    uploaded_image = uploaded_image.resize((240, 240))
    
    # Display the uploaded image
    plt.imshow(uploaded_image)
    plt.axis('off')
    plt.title('Uploaded Image')
    plt.show()
    
    # Get image dimensions
    width, height = uploaded_image.size
    print("Image dimensions:", width, "x", height)
    
    # Get image format
    image_format = uploaded_image.format
    print("Image format:", image_format)
    
    # Get image mode
    image_mode = uploaded_image.mode
    print("Image mode:", image_mode)
    
    # Convert image to numpy array
    image_array = np.array(uploaded_image)
    print("Image array shape:", image_array.shape)

# Path to the uploaded image
uploaded_image_path = "/kaggle/input/smoke-demo/smoke_demo.jpg"  # Replace with the actual path to your uploaded image

# Test the uploaded image
test_uploaded_image(uploaded_image_path)
# Out:
# Image dimensions: 240 x 240
# Image format: None
# Image mode: RGB
# Image array shape: (240, 240, 3)

# %%
# Out:
# Image dimensions: 240 x 240
# Image format: JPEG
# Image mode: RGB
# Image array shape: (240, 240, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import torch
import torchvision.transforms as transforms
from torchvision import models

# %%
# Function to load the smoke detection model
def load_smoke_detection_model():
    model = models.resnet18(pretrained=True)
    num_ftrs = model.fc.in_features
    model.fc = torch.nn.Linear(num_ftrs, 2)  # Assuming the model predicts 2 classes: Smoke and Non-smoke
    model.load_state_dict(torch.load("/kaggle/working/runs/detect/train/weights/best.pt"))
    model.eval()
    return model

# Function to preprocess the image
def preprocess_image(image_path):
    image = Image.open(image_path).convert('RGB')
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    input_tensor = preprocess(image)
    input_batch = input_tensor.unsqueeze(0)
    return input_batch

# Function to perform inference and detect smoke in the image
def detect_smoke(image_path, smoke_detection_model):
    input_batch = preprocess_image(image_path)
    with torch.no_grad():
        output = smoke_detection_model(input_batch)
    _, predicted = torch.max(output, 1)
    return predicted.item() == 1  # Assuming 1 represents the class for smoke

# Path to the uploaded image
uploaded_image_path = "/kaggle/input/smoke-demo/smoke_demo.jpg"  # Replace with the actual path to your uploaded image

# Load the smoke detection model
smoke_detection_model = load_smoke_detection_model()

# Test the uploaded image for smoke detection
is_smoke_detected = detect_smoke(uploaded_image_path, smoke_detection_model)

# Display the result
if is_smoke_detected:
    print("Smoke detected in the image.")
else:
    print("No smoke detected in the image.")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[69], line 42
#      39 uploaded_image_path = "/kaggle/input/smoke-demo/smoke_demo.jpg"  # Replace with the actual path to your uploaded image
#      41 # Load the smoke detection model
# ---> 42 smoke_detection_model = load_smoke_detection_model()
#      44 # Test the uploaded image for smoke detection
#      45 is_smoke_detected = detect_smoke(uploaded_image_path, smoke_detection_model)
#
# Cell In[69], line 13, in load_smoke_detection_model()
#      11 num_ftrs = model.fc.in_features
#      12 model.fc = torch.nn.Linear(num_ftrs, 2)  # Assuming the model predicts 2 classes: Smoke and Non-smoke
# ---> 13 model.load_state_dict(torch.load("/kaggle/working/runs/detect/train/weights/best.pt"))
#      14 model.eval()
#      15 return model
#
# ...

# %%
# load the best model and trained weights
model = create_model(num_classes=1)
checkpoint = torch.load("/kaggle/working/runs/detect/train/weights/best.pt")
model = checkpoint['model']
# checkpoint = torch.load('/kaggle/working/runs/detect/train/weights/best.pt', map_location=DEVICE)
# model.load_state_dict(checkpoint[model.state_dict])
model.to(DEVICE).eval()
# any detection having score below this will be discarded, i.e bbox with scores more than 0.8
# will be shown, less than the threshold will not be shown
detection_threshold = 0.8

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import imageio

# %%
# def plot_predicted(input_image):
#     image = plt.imread(os.path.join(input_image))
#     img = image.copy()
#     input_image = os.path.join(input_image)
#     # Bring color channels to front
#     img = np.transpose(img, (2, 0, 1)).astype(np.float32)
#     # Convert to tensor
#     img = torch.tensor(img, dtype=torch.float).cuda() # Assuming GPU enabled
#     # Add batch dimension
#     img = torch.unsqueeze(img, 0)
#     with torch.no_grad(): # Forward pass
#         outputs = model(img.to(DEVICE))
#     # Load all detections to CPU for further operations
#     outputs = [{k: v.to('gpu') for k, v in t.items()} for t in outputs]
#     # Draw predicted bounding boxes
#     fig, ax = plt.subplots(figsize=(16,8))
#     ax = img_show(image, ax=ax)
#     # Carry further only if there are detected boxes
#     if len(outputs[0]['boxes']) > 0:
#         boxes = outputs[0]['boxes'].data.numpy() # Convert tensor coordinates to numpy array
#         scores = outputs[0]['scores'].data.numpy()
#         lbls = outputs[0]['labels'].data.numpy()
#         # Filter out boxes according to detection_threshold
#         boxes = boxes[scores > detection_threshold].astype(np.int32)
#         lbls = lbls[scores > detection_threshold].astype(np.int32)
#         # Draw predicted boxes
#         for box, lbl in zip(boxes, lbls):
#             draw_box(ax, box, CLASS_NAME[lbl])
#     plt.show()
# # Example usage
# input_image = "/kaggle/input/smoke-demo/smoke_demo.jpg"
# plot_predicted(input_image)



# import torch
# import numpy as np
# import matplotlib.pyplot as plt
# import os

def plot_predicted(input_image, model, DEVICE, detection_threshold=0.5, CLASS_NAME=None):
    # Read and preprocess the image
    image = plt.imread(os.path.join(input_image))
    img = image.copy()
    input_image = os.path.join(input_image)
    img = np.transpose(img, (2, 0, 1)).astype(np.float32)  # Bring color channels to front
    img = torch.tensor(img, dtype=torch.float).cuda()     # Convert to tensor
    img = torch.unsqueeze(img, 0)                         # Add batch dimension
    
    # Forward pass
    with torch.no_grad():
        outputs = model(img.to(DEVICE))
    
    # Load all detections to CPU for further operations
    outputs = [{k: v.to('cpu') for k, v in t.items()} for t in outputs]
    
    # Draw predicted bounding boxes
    fig, ax = plt.subplots(figsize=(16,8))
    ax.imshow(image)
    
    # Carry further only if there are detected boxes
    if len(outputs[0]['boxes']) > 0:
        boxes = outputs[0]['boxes'].data.numpy()          # Convert tensor coordinates to numpy array
        scores = outputs[0]['scores'].data.numpy()
        lbls = outputs[0]['labels'].data.numpy()
        
        # Filter out boxes according to detection_threshold
        boxes = boxes[scores > detection_threshold].astype(np.int32)
        lbls = lbls[scores > detection_threshold].astype(np.int32)
        
        # Draw predicted boxes
        for box, lbl in zip(boxes, lbls):
            draw_box(ax, box, CLASS_NAME[lbl])
    
    plt.show()

# Example usage
input_image = "/kaggle/input/smoke-demo/smoke_demo.jpg"
plot_predicted(input_image, model, DEVICE)  # Assuming model and DEVICE are defined elsewhere
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[55], line 79
#      77 # Example usage
#      78 input_image = "/kaggle/input/smoke-demo/smoke_demo.jpg"
# ---> 79 plot_predicted(input_image, model, DEVICE)  # Assuming model and DEVICE are defined elsewhere
#
# Cell In[55], line 52, in plot_predicted(input_image, model, DEVICE, detection_threshold, CLASS_NAME)
#      50 # Forward pass
#      51 with torch.no_grad():
# ---> 52     outputs = model(img.to(DEVICE))
#      54 # Load all detections to CPU for further operations
#      55 outputs = [{k: v.to('cpu') for k, v in t.items()} for t in outputs]
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# ...
